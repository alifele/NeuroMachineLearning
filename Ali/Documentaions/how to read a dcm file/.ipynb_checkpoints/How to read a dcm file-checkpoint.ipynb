# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from pydicom import *
from pydicom.data import get_testdata_files

# %%
filename = get_testdata_files('CT_small.dcm')[0]
dataset = pydicom.dcmread(filename)

# %%
plt.imshow(dataset.pixel_array)

# %%
file = dcmread('testdata.dcm')

# %%
file
# Out:
# (0008, 0000) Group Length                        UL: 1166
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY']
# (0008, 0012) Instance Creation Date              DA: '20110620'
# (0008, 0013) Instance Creation Time              TM: '161704'
# (0008, 0016) SOP Class UID                       UI: Positron Emission Tomography Image Storage
# (0008, 0018) SOP Instance UID                    UI: 2.16.124.113543.6006.99.9187060062259405294
# (0008, 0020) Study Date                          DA: '20110620'
# (0008, 0021) Series Date                         DA: '20110620'
# (0008, 0022) Acquisition Date                    DA: '20110620'
# (0008, 0023) Content Date                        DA: '20110620'
# (0008, 0030) Study Time                          TM: '160842.000000'
# (0008, 0031) Series Time                         TM: '161617'
# (0008, 0032) Acquisition Time                    TM: '163203'
# (0008, 0033) Content Time                        TM: '161704'
# (0008, 0050) Accession Number                    SH: '16320977'
# (0008, 0060) Modality                            CS: 'PT'
# (0008, 0070) Manufacturer                        LO: 'Philips Medical Systems'
# (0008, 0080) Institution Name                    LO: 'OHSU'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'PET BRAIN METABOLIC'
# (0008, 103e) Series Description                  LO: 'ADNI Brain PET: Raw AV45'
# (0008, 1060) Name of Physician(s) Reading Study  PN: ''
# (0008, 1070) Operators' Name                     PN: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'GEMINI TF TOF 16'
# (0008, 1110)  Referenced Study Sequence   1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: 2.16.124.113543.6006.99.06282883507200984267
#    (0008, 1155) Referenced SOP Instance UID         UI: 2.16.124.113543.6006.99.4363772296639588053
#    ---------
# (0008, 1111)  Referenced Performed Procedure Step Sequence   1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: 2.16.124.113543.6006.99.06279230344779385614
#    (0008, 1155) Referenced SOP Instance UID         UI: 2.16.124.113543.6006.99.05028606839886510068
#    ---------
# (0008, 1120)  Referenced Patient Sequence   1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: 2.16.124.113543.6006.99.06278070223545294329
#    (0008, 1155) Referenced SOP Instance UID         UI: 2.16.124.113543.6006.99.1365710019095302909
#    ---------
# (0008, 1250)  Related Series Sequence   1 item(s) ----
#    (0020, 000d) Study Instance UID                  UI: 2.16.124.113543.6006.99.4363772296639588053
#    (0020, 000e) Series Instance UID                 UI: 2.16.124.113543.6006.99.05389333173435485447
#    (0040, a170)  Purpose of Reference Code Sequence   1 item(s) ----
#       (0008, 0100) Code Value                          SH: '122403'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'For Attenuation Correction'
#       ---------
#    ---------
# (0008, 9121)  Referenced Raw Data Sequence   1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: 2.16.124.113543.6006.99.8463325660134705548
#    (0008, 1155) Referenced SOP Instance UID         UI: 2.16.124.113543.6006.99.4481373232240519233
#    ---------
# (0010, 0000) Group Length                        UL: 106
# (0010, 0010) Patient's Name                      PN: '002_S_0413'
# (0010, 0020) Patient ID                          LO: '002_S_0413'
# (0010, 0030) Patient's Birth Date                DA: '19291231'
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1010) Patient's Age                       AS: '081Y'
# (0010, 1020) Patient's Size                      DS: "1.680"
# (0010, 1030) Patient's Weight                    DS: "54.430000"
# (0018, 0000) Group Length                        UL: 148
# (0018, 0050) Slice Thickness                     DS: "2"
# (0018, 1000) Device Serial Number                LO: '4X3InxozVe8I'
# (0018, 1020) Software Version(s)                 LO: ['9.5', 'PMSPT1.44']
# (0018, 1100) Reconstruction Diameter             DS: "256.000000"
# (0018, 1147) Field of View Shape                 CS: 'CYLINDRICAL RING'
# (0018, 1149) Field of View Dimension(s)          IS: ['903', '180']
# (0018, 1181) Collimator Type                     CS: 'NONE'
# (0018, 1242) Actual Frame Duration               IS: "299996"
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 0000) Group Length                        UL: 326
# (0020, 000d) Study Instance UID                  UI: 2.16.124.113543.6006.99.4363772296639588053
# (0020, 000e) Series Instance UID                 UI: 2.16.124.113543.6006.99.02735301827811289251
# (0020, 0010) Study ID                            SH: '11386'
# (0020, 0011) Series Number                       IS: "140460"
# (0020, 0013) Instance Number                     IS: "63"
# (0020, 0032) Image Position (Patient)            DS: ['-127.585938', '-72.585938', '1472.500000']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.16.124.113543.6006.99.04995534317747718543
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "1472.500000"
# (0028, 0000) Group Length                        UL: 244
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 128
# (0028, 0011) Columns                             US: 128
# (0028, 0030) Pixel Spacing                       DS: ['2.000000', '2.000000']
# (0028, 0051) Corrected Image                     CS: ['DECY', 'RADL', 'ATTN', 'SCAT', 'DTIM', 'RAN', 'NORM']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 731
# (0028, 1050) Window Center                       DS: "5.680000e+02"
# (0028, 1051) Window Width                        DS: "1.136000e+03"
# (0028, 1052) Rescale Intercept                   DS: "0"
# (0028, 1053) Rescale Slope                       DS: "1.000000"
# (0031, 0000) Private Creator                     UL: 22
# (0031, 1000) Private tag data                    CS: 'N'
# (0031, 1001) Private tag data                    UL: 1308614769
# (0032, 0000) Group Length                        UL: 30
# (0032, 000a) Study Status ID                     CS: 'COMPLETED'
# (0032, 000c) Study Priority ID                   CS: 'LOW'
# (0033, 0000) Private Creator                     UL: 28
# (0033, 1004) Private tag data                    CS: 'PET BRAIN METABOLIC'
# (0040, 0000) Group Length                        UL: 34
# (0040, 0245) Performed Procedure Step Start Time TM: '160842'
# (0040, 0275)  Request Attributes Sequence   1 item(s) ----
#
#    ---------
# (0054, 0000) Group Length                        UL: 732
# (0054, 0016)  Radiopharmaceutical Information Sequence   1 item(s) ----
#    (0018, 0031) Radiopharmaceutical                 LO: 'Fluorodeoxyglucose F^18^'
#    (0018, 1072) Radiopharmaceutical Start Time      TM: '153000'
#    (0018, 1074) Radionuclide Total Dose             DS: "350760000"
#    (0018, 1075) Radionuclide Half Life              DS: "6586.199707"
#    (0018, 1076) Radionuclide Positron Fraction      DS: "0.967"
#    (0054, 0300)  Radionuclide Code Sequence   1 item(s) ----
#       (0008, 0100) Code Value                          SH: 'C-111A1'
#       (0008, 0102) Coding Scheme Designator            SH: 'SNM3'
#       (0008, 0104) Code Meaning                        LO: '^18^Fluorine'
#       ---------
#    (0054, 0302)  Administration Route Code Sequence   1 item(s) ----
#       (0008, 0100) Code Value                          SH: 'G-D101'
#       (0008, 0102) Coding Scheme Designator            SH: 'SNM3'
#       (0008, 0104) Code Meaning                        LO: 'Intravenous route'
#       ---------
#    (0054, 0304)  Radiopharmaceutical Code Sequence   1 item(s) ----
#       (0008, 0100) Code Value                          SH: 'C-B1031'
#       (0008, 0102) Coding Scheme Designator            SH: 'SRT'
#       (0008, 0104) Code Meaning                        LO: 'Fluorodeoxyglucose F^18^'
#       ---------
#    ---------
# (0054, 0081) Number of Slices                    US: 90
# (0054, 0101) Number of Time Slices               US: 4
# (0054, 0202) Type of Detector Motion             CS: 'NONE'
# (0054, 0410)  Patient Orientation Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'F-10450'
#    (0008, 0102) Coding Scheme Designator            SH: '99SDM'
#    (0008, 0104) Code Meaning                        LO: 'recumbent'
#    (0054, 0412)  Patient Orientation Modifier Code Sequence   1 item(s) ----
#       (0008, 0100) Code Value                          SH: 'F-10340'
#       (0008, 0102) Coding Scheme Designator            SH: '99SDM'
#       (0008, 0104) Code Meaning                        LO: 'supine'
#       ---------
#    ---------
# (0054, 0414)  Patient Gantry Relationship Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'G-5190'
#    (0008, 0102) Coding Scheme Designator            SH: '99SDM'
#    (0008, 0104) Code Meaning                        LO: 'headfirst'
#    ---------
# (0054, 1000) Series Type                         CS: ['DYNAMIC', 'IMAGE']
# (0054, 1001) Units                               CS: 'CNTS'
# (0054, 1002) Counts Source                       CS: 'EMISSION'
# (0054, 1100) Randoms Correction Method           CS: 'DLYD'
# (0054, 1101) Attenuation Correction Method       LO: 'CTAC-SG'
# (0054, 1102) Decay Correction                    CS: 'START'
# (0054, 1103) Reconstruction Method               LO: 'LOR-RAMLA'
# (0054, 1105) Scatter Correction Method           LO: 'SS-SIMUL'
# (0054, 1300) Frame Reference Time                DS: "1095996"
# (0054, 1321) Decay Factor                        DS: "1.0"
# (0054, 1330) Image Index                         US: 333
# (00e1, 0000) Private Creator                     UL: 52
# (00e1, 10c2) Private tag data                    UI: 2.16.124.113543.6006.99.08739011577955547756
# (7053, 0000) Private Creator                     UL: 112
# (7053, 1013) Private tag data                    SS: 0
# (7053, 1014) Private tag data                    SS: 0
# (7053, 1015) Private tag data                    SS: 0
# (7053, 1016) Private tag data                    SS: 0
# (7053, 1017) Private tag data                    SS: 0
# (7053, 1018) Private tag data                    SS: 0
# (7053, 10c2) Private tag data                    UI: 2.16.124.113543.6006.99.08739011577955547756
# (7fe0, 0010) Pixel Data                          OW: Array of 32768 elements

# %%
plt.imshow(file.pixel_array)
